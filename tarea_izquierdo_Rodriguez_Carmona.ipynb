# %% [markdown]
# <a href="https://colab.research.google.com/github/Carmodann1311/IA_Calidadypreparacion/blob/main/tarea_izquierdo_Rodriguez_Carmona.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/Tarea y tarea extra - Hoja 1.csv', index_col=0)
df.loc[:]
# Out:
#                  maynez Xochitl Claudia              Estados maynez.1  \
# alcaldia
# GAM               8.74%  21.09%  68.05%       Aguascalientes    8.93%
# Azcapotzalco      9.02%  34.65%  54.50%      Baja California    9.95%
# Iztapalapa        8.04%  20.30%  69.61%  Baja California Sur    8.77%
# Tlaplan           9.29%  31.76%  56.83%             Campeche   20.99%
# MAC               7.56%  40.27%  50.20%             Coahuila    5.40%
# Coyoacán          8.24%  40.02%  49.64%               Colima   13.33%
# Tláhuac          10.43%  21.33%  66.20%              Chiapas    7.40%
# Miguel Hidalgo    6.72%  50.38%  41.32%            Chihuahua    9.55%
# Venustiano Carr   9.30%  33.74%  54.91%     Ciudad de Mexico    8.35%
# cuauhtémoc        7.92%  41.89%  47.95%              Durango    7.21%
# Iztacalco         9.40%  32.94%  55.68%           Guanajuato   10.56%
# Benito Juárez     5.40%  62.88%  29.93%             Guerrero    6.38%
# Alvaro Obregón    8.17%  32.77%  57.01%              Hidalgo   10.33%
# Xochimilco       10.68%  20.93%  66.01%              Jalisco   17.31%
# NaN                 NaN     NaN     NaN               Mexico   10.71%
# NaN                 NaN     NaN     NaN            Michoacan   12.09%
# NaN                 NaN     NaN     NaN              Morelos   12.76%
# NaN                 NaN     NaN     NaN              Nayarit   13.77%
# NaN                 NaN     NaN     NaN           Nuevo Leon   18.06%
# NaN                 NaN     NaN     NaN               Oaxaca    6.60%
# NaN                 NaN     NaN     NaN               Puebla   76.37%
# NaN                 NaN     NaN     NaN            Queretaro   65.19%
# NaN                 NaN     NaN     NaN         Quintana Roo    7.72%
# NaN                 NaN     NaN     NaN      San Luis Potosi   10.75%
# NaN                 NaN     NaN     NaN              Sinaloa    7.76%
# NaN                 NaN     NaN     NaN               Sonora    9.18%
# NaN                 NaN     NaN     NaN              Tabasco    5.93%
# NaN                 NaN     NaN     NaN          Taumailipas    9.38%
# NaN                 NaN     NaN     NaN             Tlaxcala   13.93%
# NaN                 NaN     NaN     NaN             Veracruz    8.02%
# NaN                 NaN     NaN     NaN              Yucatan    6.85%
# NaN                 NaN     NaN     NaN            Zacatecas   16.89%
#
#                 Xochitl.1 Claudia.1
# alcaldia
# GAM                45.97%    42.73%
# Azcapotzalco       21.19%    66.65%
# Iztapalapa         29.74%    59.14%
# Tlaplan            15.48%    61.30%
# MAC                38.85%    53.72%
# Coyoacán           29.96%    54.41%
# Tláhuac            16.69%    71.55%
# Miguel Hidalgo     34.03%    53.86%
# Venustiano Carr    34.55%    55.20%
# cuauhtémoc         32.13%    58.45%
# Iztacalco          39.99%    47.22%
# Benito Juárez      18.78%    71.66%
# Alvaro Obregón     19.84%    67.44%
# Xochimilco         35.77%    44.44%
# NaN                26.50%    60.60%
# NaN                29.32%    55.07%
# NaN                21.34%    63.80%
# NaN                20.21%    63.27%
# NaN                34.64%    45.21%
# NaN                14.41%    76.37%
# NaN                21.75%    65.19%
# NaN                36.89%    51.08%
# NaN                16.80%    73.17%
# NaN                25.47%    60.51%
# NaN                24.53%    65.60%
# NaN                24.79%    63.92%
# NaN                11.13%    80.53%
# NaN                26.27%    62.33%
# NaN                14.73%    69.20%
# NaN                23.05%    66.45%
# NaN                30.40%    60.69%
# NaN                29.92%    50.35%

# %% [markdown]
# **maynez**
# media = 9.66
# desviacion estandar = 1.38
#
# **xochilt**
# media = 33.07
# desviacion estandar = 11.52
#
# **claudia**
#
# media = 53.76
# desviacion estandar = 10.99

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [9.66, 33.07, 53.76]  # Medias de las distribuciones
desviaciones_estandar = [1.38, 11.52, 10.99]  # Desviaciones estándar de las distribuciones
n = 1000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Graficar las tres variables aleatorias juntas
plt.figure(figsize=(10, 6))
for i in range(3):
    plt.hist(variables_aleatorias[i], bins=30, density=True, alpha=0.6, label=f'Variable {i+1}')

plt.title('Histograma de tres variables aleatorias normales')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [9.66, 33.07, 53.76]  # Medias de las distribuciones
desviaciones_estandar = [1.38, 11.52, 10.99]  # Desviaciones estándar de las distribuciones
n = 100000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Graficar las tres variables aleatorias juntas
plt.figure(figsize=(10, 6))
for i in range(3):
    plt.hist(variables_aleatorias[i], bins=30, density=True, alpha=0.6, label=f'Variable {i+1}')

plt.title('Histograma de tres variables aleatorias normales')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [9.66, 33.07, 53.76]  # Medias de las distribuciones
desviaciones_estandar = [1.38, 11.52, 10.99]  # Desviaciones estándar de las distribuciones
n = 1000000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Graficar las tres variables aleatorias juntas
plt.figure(figsize=(10, 6))
for i in range(3):
    plt.hist(variables_aleatorias[i], bins=30, density=True, alpha=0.6, label=f'Variable {i+1}')

plt.title('Histograma de tres variables aleatorias normales')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [9.66, 33.07, 53.76]  # Medias de las distribuciones
desviaciones_estandar = [1.38, 11.52, 10.99]  # Desviaciones estándar de las distribuciones
n = 1000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Crear un DataFrame de pandas con los datos
df = pd.DataFrame({'Variable 1': variables_aleatorias[0],
                   'Variable 2': variables_aleatorias[1],
                   'Variable 3': variables_aleatorias[2]})

# Calcular estadísticas resumidas
resumen_estadistico = df.describe()

# Mostrar la tabla dinámica
print("Tabla dinámica de las variables aleatorias:")
print(resumen_estadistico)
# Out:
# Tabla dinámica de las variables aleatorias:
#         Variable 1   Variable 2   Variable 3
# count  1000.000000  1000.000000  1000.000000
# mean      9.687328    33.608925    54.214742
# std       1.413828    11.625682    11.013305
# min       5.644654    -4.082783    15.869584
# 25%       8.727360    25.783161    46.841510
# 50%       9.717342    33.898193    54.086837
# 75%      10.614857    41.255565    61.589121
# max      15.178031    65.779511    87.007390

# %% [markdown]
# ***TAREA EXTRA ESTADOS DE LA REPUBLICA***

# %% [markdown]
# **MAYNEZ**
# MEDIA= 13.59
# DESVIACION ESTANDAR= 18.05
#
# **XOCHILT**
# MEDIA= 24.44
# DESVIACION ESTANDAR= 8.92
#
# **CLAUDIA**
# MEDIA= 58.92
# DESVIACION ESTANDAR= 8.92

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [13.59, 24.44, 58.92]  # Medias de las distribuciones
desviaciones_estandar = [18.05, 8.92, 8.92]  # Desviaciones estándar de las distribuciones
n = 1000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Graficar las tres variables aleatorias juntas
plt.figure(figsize=(10, 6))
for i in range(3):
    plt.hist(variables_aleatorias[i], bins=30, density=True, alpha=0.6, label=f'Variable {i+1}')

plt.title('Histograma de tres variables aleatorias normales')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [13.59, 24.44, 58.92]  # Medias de las distribuciones
desviaciones_estandar = [18.05, 8.92, 8.92]  # Desviaciones estándar de las distribuciones
n = 10000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Graficar las tres variables aleatorias juntas
plt.figure(figsize=(10, 6))
for i in range(3):
    plt.hist(variables_aleatorias[i], bins=30, density=True, alpha=0.6, label=f'Variable {i+1}')

plt.title('Histograma de tres variables aleatorias normales')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [13.59, 24.44, 58.92]  # Medias de las distribuciones
desviaciones_estandar = [18.05, 8.92, 8.92]  # Desviaciones estándar de las distribuciones
n = 100000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Graficar las tres variables aleatorias juntas
plt.figure(figsize=(10, 6))
for i in range(3):
    plt.hist(variables_aleatorias[i], bins=30, density=True, alpha=0.6, label=f'Variable {i+1}')

plt.title('Histograma de tres variables aleatorias normales')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [13.59, 24.44, 58.92]  # Medias de las distribuciones
desviaciones_estandar = [18.05, 8.92, 8.92]  # Desviaciones estándar de las distribuciones
n = 1000000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Graficar las tres variables aleatorias juntas
plt.figure(figsize=(10, 6))
for i in range(3):
    plt.hist(variables_aleatorias[i], bins=30, density=True, alpha=0.6, label=f'Variable {i+1}')

plt.title('Histograma de tres variables aleatorias normales')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [13.59, 24.44, 58.92]  # Medias de las distribuciones
desviaciones_estandar = [18.05, 8.92, 8.92]  # Desviaciones estándar de las distribuciones
n = 10000000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Graficar las tres variables aleatorias juntas
plt.figure(figsize=(10, 6))
for i in range(3):
    plt.hist(variables_aleatorias[i], bins=30, density=True, alpha=0.6, label=f'Variable {i+1}')

plt.title('Histograma de tres variables aleatorias normales')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [13.59, 24.44, 58.92]  # Medias de las distribuciones
desviaciones_estandar = [18.05, 8.92, 8.92]  # Desviaciones estándar de las distribuciones
n = 1000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Crear un DataFrame de pandas con los datos
df = pd.DataFrame({'Variable 1': variables_aleatorias[0],
                   'Variable 2': variables_aleatorias[1],
                   'Variable 3': variables_aleatorias[2]})

# Calcular estadísticas resumidas
resumen_estadistico = df.describe()

# Mostrar la tabla dinámica
print("Tabla dinámica de las variables aleatorias:")
print(resumen_estadistico)
# Out:
# Tabla dinámica de las variables aleatorias:
#         Variable 1   Variable 2   Variable 3
# count  1000.000000  1000.000000  1000.000000
# mean     13.471416    24.702105    58.777219
# std      18.612267     8.577155     8.831740
# min     -48.562365    -3.042332    32.523040
# 25%       1.675826    18.879198    52.844060
# 50%      13.718943    24.812362    58.704149
# 75%      25.754290    30.480285    64.459922
# max      84.893270    59.666134    89.822734
