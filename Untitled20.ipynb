# %% [markdown]
# <a href="https://colab.research.google.com/github/Carmodann1311/IA_Calidadypreparacion/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de la distribución normal
media = 11.1714  # Media de la distribución
desviacion_estandar = 3.567  # Desviación estándar de la distribución

# Número de muestras a simular
numero_de_muestras = 1000

# Simular la variable aleatoria normal
variable_aleatoria_normal = simular_variable_aleatoria_normal(media, desviacion_estandar, numero_de_muestras)

# Imprimir algunos de los valores simulados
print("Algunos valores simulados de la variable aleatoria normal:")
print(variable_aleatoria_normal[:10])

# Visualizar la distribución de los valores simulados
plt.hist(variable_aleatoria_normal, bins=30, density=True, alpha=0.6, color='g')
plt.title('Histograma de la variable aleatoria normal')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.show()
# Out:
# Algunos valores simulados de la variable aleatoria normal:
# [14.39421607  6.74563113 16.6942148  10.59237272 10.52209975 14.86860277
#  11.53237108 13.90865621 12.82842858 13.45486392]

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de la distribución normal
media = 31.0554  # Media de la distribución
desviacion_estandar = 11.0468  # Desviación estándar de la distribución

# Número de muestras a simular
numero_de_muestras = 1000

# Simular la variable aleatoria normal
variable_aleatoria_normal = simular_variable_aleatoria_normal(media, desviacion_estandar, numero_de_muestras)

# Imprimir algunos de los valores simulados
print("Algunos valores simulados de la variable aleatoria normal:")
print(variable_aleatoria_normal[:10])

# Visualizar la distribución de los valores simulados
plt.hist(variable_aleatoria_normal, bins=30, density=True, alpha=0.6, color='g')
plt.title('Histograma de la variable aleatoria normal')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.show()
# Out:
# Algunos valores simulados de la variable aleatoria normal:
# [22.08166086 16.19262131 26.4039317  33.84976472 30.84202234 22.20833184
#  27.42680125  2.82616844 26.55369698 14.24791802]

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de la distribución normal
media = 56.2044 # Media de la distribución
desviacion_estandar = 11.9073  # Desviación estándar de la distribución

# Número de muestras a simular
numero_de_muestras = 1000

# Simular la variable aleatoria normal
variable_aleatoria_normal = simular_variable_aleatoria_normal(media, desviacion_estandar, numero_de_muestras)

# Imprimir algunos de los valores simulados
print("Algunos valores simulados de la variable aleatoria normal:")
print(variable_aleatoria_normal[:10])

# Visualizar la distribución de los valores simulados
plt.hist(variable_aleatoria_normal, bins=30, density=True, alpha=0.6, color='g')
plt.title('Histograma de la variable aleatoria normal')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.show()
# Out:
# Algunos valores simulados de la variable aleatoria normal:
# [53.22980179 60.18626188 47.18196958 62.61407505 56.84634745 49.79441148
#  59.04729836 73.05026373 38.91211515 38.55559616]

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [11.1714, 31.0554, 56.2044]  # Medias de las distribuciones
desviaciones_estandar = [3.567, 11.0468, 11.9073]  # Desviaciones estándar de las distribuciones
n = 1000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Graficar las tres variables aleatorias juntas
plt.figure(figsize=(10, 6))
for i in range(3):
    plt.hist(variables_aleatorias[i], bins=30, density=True, alpha=0.6, label=f'Variable {i+1}')

plt.title('Histograma de tres variables aleatorias normales')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.legend()
plt.grid(True)
plt.show()
