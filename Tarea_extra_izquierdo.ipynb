# %% [markdown]
# <a href="https://colab.research.google.com/github/Carmodann1311/IA_Calidadypreparacion/blob/main/Tarea_extra_izquierdo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/tarea izquierdo extra - Hoja 1.csv', index_col=0)
df.loc[:]
# Out:
#                       maynez Xochitl  Claudia
# Estados
# Aguascalientes         8.93%   45.97%   42.73%
# Baja California        9.95%   21.19%   66.65%
# Baja California Sur    8.77%   29.74%   59.14%
# Campeche              20.99%   15.48%   61.30%
# Coahuila               5.40%   38.85%   53.72%
# Colima                13.33%   29.96%   54.41%
# Chiapas                7.40%   16.69%   71.55%
# Chihuahua              9.55%   34.03%   53.86%
# Ciudad de Mexico       8.35%   34.55%   55.20%
# Durango                7.21%   32.13%   58.45%
# Guanajuato            10.56%   39.99%   47.22%
# Guerrero               6.38%   18.78%   71.66%
# Hidalgo               10.33%   19.84%   67.44%
# Jalisco               17.31%   35.77%   44.44%
# Mexico                10.71%   26.50%   60.60%
# Michoacan             12.09%   29.32%   55.07%
# Morelos               12.76%   21.34%   63.80%
# Nayarit               13.77%   20.21%   63.27%
# Nuevo Leon            18.06%   34.64%   45.21%
# Oaxaca                 6.60%   14.41%   76.37%
# Puebla                76.37%   21.75%   65.19%
# Queretaro             65.19%   36.89%   51.08%
# Quintana Roo           7.72%   16.80%   73.17%
# San Luis Potosi       10.75%   25.47%   60.51%
# Sinaloa                7.76%   24.53%   65.60%
# Sonora                 9.18%   24.79%   63.92%
# Tabasco                5.93%   11.13%   80.53%
# Taumailipas            9.38%   26.27%   62.33%
# Tlaxcala              13.93%   14.73%   69.20%
# Veracruz               8.02%   23.05%   66.45%
# Yucatan                6.85%   30.40%   60.69%
# Zacatecas             16.89%   29.92%   50.35%

# %% [markdown]
# maynez: Media ≈ 15.03
# Desviación Estándar ≈ 21.61 xoxchilt: Media ≈ 26.27
# Desviación Estándar ≈ 8.87 claudia: Media ≈ 59.14
# Desviación Estándar ≈ 10.94

# %%
import pandas as pd

# Cargar el archivo CSV
file_path = '/content/tarea izquierdo extra - Hoja 1.csv'  # Reemplaza esto con la ruta a tu archivo CSV
data = pd.read_csv(file_path)

# Mostrar las primeras filas del dataframe
print("Datos originales:")
print(data.head())

# Eliminar filas con datos nulos
data_cleaned = data.dropna()

# Mostrar las primeras filas del dataframe limpio
print("Datos después de eliminar nulos:")
print(data_cleaned.head())

# Guardar el dataframe limpio en un nuevo archivo CSV (opcional)
data_cleaned.to_csv('/content/tarea izquierdo extra.csv', index=False)
# Out:
# Datos originales:
#                Estados   maynez Xochitl  Claudia
# 0        Aguascalientes   8.93%   45.97%   42.73%
# 1       Baja California   9.95%   21.19%   66.65%
# 2  Baja California Sur    8.77%   29.74%   59.14%
# 3             Campeche   20.99%   15.48%   61.30%
# 4             Coahuila    5.40%   38.85%   53.72%
# Datos después de eliminar nulos:
#                Estados   maynez Xochitl  Claudia
# 0        Aguascalientes   8.93%   45.97%   42.73%
# 1       Baja California   9.95%   21.19%   66.65%
# 2  Baja California Sur    8.77%   29.74%   59.14%
# 3             Campeche   20.99%   15.48%   61.30%
# 4             Coahuila    5.40%   38.85%   53.72%

# %%
import pandas as pd
df = pd.read_csv('/content/tarea izquierdo extra.csv', index_col=0)
df.loc[:]
# Out:
#                       maynez Xochitl  Claudia
# Estados
# Aguascalientes         8.93%   45.97%   42.73%
# Baja California        9.95%   21.19%   66.65%
# Baja California Sur    8.77%   29.74%   59.14%
# Campeche              20.99%   15.48%   61.30%
# Coahuila               5.40%   38.85%   53.72%
# Colima                13.33%   29.96%   54.41%
# Chiapas                7.40%   16.69%   71.55%
# Chihuahua              9.55%   34.03%   53.86%
# Ciudad de Mexico       8.35%   34.55%   55.20%
# Durango                7.21%   32.13%   58.45%
# Guanajuato            10.56%   39.99%   47.22%
# Guerrero               6.38%   18.78%   71.66%
# Hidalgo               10.33%   19.84%   67.44%
# Jalisco               17.31%   35.77%   44.44%
# Mexico                10.71%   26.50%   60.60%
# Michoacan             12.09%   29.32%   55.07%
# Morelos               12.76%   21.34%   63.80%
# Nayarit               13.77%   20.21%   63.27%
# Nuevo Leon            18.06%   34.64%   45.21%
# Oaxaca                 6.60%   14.41%   76.37%
# Puebla                76.37%   21.75%   65.19%
# Queretaro             65.19%   36.89%   51.08%
# Quintana Roo           7.72%   16.80%   73.17%
# San Luis Potosi       10.75%   25.47%   60.51%
# Sinaloa                7.76%   24.53%   65.60%
# Sonora                 9.18%   24.79%   63.92%
# Tabasco                5.93%   11.13%   80.53%
# Taumailipas            9.38%   26.27%   62.33%
# Tlaxcala              13.93%   14.73%   69.20%
# Veracruz               8.02%   23.05%   66.45%
# Yucatan                6.85%   30.40%   60.69%
# Zacatecas             16.89%   29.92%   50.35%

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [15.03, 26.27, 59.14]  # Medias de las distribuciones
desviaciones_estandar = [21.61, 8.87, 10.94]  # Desviaciones estándar de las distribuciones
n = 1000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Graficar las tres variables aleatorias juntas
plt.figure(figsize=(10, 6))
for i in range(3):
    plt.hist(variables_aleatorias[i], bins=30, density=True, alpha=0.6, label=f'Variable {i+1}')

plt.title('Histograma de tres variables aleatorias normales')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [13.59, 24.44, 58.92]  # Medias de las distribuciones
desviaciones_estandar = [18.05, 9.70, 8.92]  # Desviaciones estándar de las distribuciones
n = 10000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Graficar las tres variables aleatorias juntas
plt.figure(figsize=(10, 6))
for i in range(3):
    plt.hist(variables_aleatorias[i], bins=30, density=True, alpha=0.6, label=f'Variable {i+1}')

plt.title('Histograma de tres variables aleatorias normales')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [13.59, 24.44, 58.92]  # Medias de las distribuciones
desviaciones_estandar = [18.05, 8.92, 8.92]  # Desviaciones estándar de las distribuciones
n = 100000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Graficar las tres variables aleatorias juntas
plt.figure(figsize=(10, 6))
for i in range(3):
    plt.hist(variables_aleatorias[i], bins=30, density=True, alpha=0.6, label=f'Variable {i+1}')

plt.title('Histograma de tres variables aleatorias normales')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [13.59, 24.44, 58.92]  # Medias de las distribuciones
desviaciones_estandar = [18.05, 8.92, 8.92]  # Desviaciones estándar de las distribuciones
n = 1000000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Graficar las tres variables aleatorias juntas
plt.figure(figsize=(10, 6))
for i in range(3):
    plt.hist(variables_aleatorias[i], bins=30, density=True, alpha=0.6, label=f'Variable {i+1}')

plt.title('Histograma de tres variables aleatorias normales')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [13.59, 24.44, 58.92]  # Medias de las distribuciones
desviaciones_estandar = [18.05, 8.92, 8.92]  # Desviaciones estándar de las distribuciones
n = 10000000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Graficar las tres variables aleatorias juntas
plt.figure(figsize=(10, 6))
for i in range(3):
    plt.hist(variables_aleatorias[i], bins=30, density=True, alpha=0.6, label=f'Variable {i+1}')

plt.title('Histograma de tres variables aleatorias normales')
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd

def simular_variable_aleatoria_normal(media, desviacion_estandar, n):
    # Generar n números aleatorios con distribución normal
    valores_aleatorios = np.random.normal(media, desviacion_estandar, n)
    return valores_aleatorios

# Parámetros de las distribuciones normales
medias = [13.59, 24.44, 58.92]  # Medias de las distribuciones
desviaciones_estandar = [18.05, 8.92, 8.92]  # Desviaciones estándar de las distribuciones
n = 1000  # Número de muestras a simular para cada distribución

# Simular las tres variables aleatorias normales
variables_aleatorias = [simular_variable_aleatoria_normal(media, desviacion_estandar, n)
                        for media, desviacion_estandar in zip(medias, desviaciones_estandar)]

# Crear un DataFrame de pandas con los datos
df = pd.DataFrame({'Variable 1': variables_aleatorias[0],
                   'Variable 2': variables_aleatorias[1],
                   'Variable 3': variables_aleatorias[2]})

# Calcular estadísticas resumidas
resumen_estadistico = df.describe()

# Mostrar la tabla dinámica
print("Tabla dinámica de las variables aleatorias:")
print(resumen_estadistico)
